# %% [markdown]
# ## 1. Dependencies/Data Read

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import re
import seaborn as sns
from datetime import datetime
sns.set(style="whitegrid")
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 100
plt.style.use('ggplot')
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df = pd.DataFrame(pd.read_csv("Kickstarter.csv"))
for i in range(1,10):
    df = df.append(pd.read_csv("Kickstarter00" + str(i) + ".csv"))
for i in range(11,49):
    df = df.append(pd.read_csv("Kickstarter0" + str(i) + ".csv"))
df = df.reset_index(drop=True)

# %% [markdown]
# ## 2. Data Cleaning

# %%
df.head()
# Out:
#    backers_count                                              blurb  \
# 0             80  I will be an artist-in-residence at Elsewhere ...
# 1             47  We are looking to bring a Visiting Sculptor fr...
# 2             80  Surrealistic oil paintings capturing the metam...
# 3             82  1000 Artists is a public art-making installati...
# 4             31  P.M.A.F.T.W. my upcoming solo show June 2012 a...
#
#                                             category  \
# 0  {"urls":{"web":{"discover":"http://www.kicksta...
# 1  {"urls":{"web":{"discover":"http://www.kicksta...
# 2  {"urls":{"web":{"discover":"http://www.kicksta...
# 3  {"urls":{"web":{"discover":"http://www.kicksta...
# 4  {"urls":{"web":{"discover":"http://www.kicksta...
#
#    converted_pledged_amount country  created_at  \
# 0                      3596      US  1325980505
# 1                      4117      US  1330727362
# 2                      3125      US  1332598567
# 3                      4586      US  1330926084
# 4                      1036      US  1332476607
#
#                                              creator currency currency_symbol  \
# 0  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 1  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 2  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 3  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 4  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
#
#    currency_trailing_code current_currency    deadline  disable_communication  \
# 0                    True              USD  1334866560                  False
# 1                    True              USD  1334959598                  False
# 2                    True              USD  1334635140                  False
# 3                    True              USD  1336440145                  False
# 4                    True              USD  1333421843                  False
#
#    fx_rate    goal          id  is_starrable  launched_at  \
# 0     1.00 2800.00  1562040083         False   1332969260
# 1     1.00 3900.00  1437561817         False   1332972398
# 2     1.00  750.00   574125813         False   1332975679
# 3     1.00 4500.00   858990141         False   1332984145
# 4     1.00 1000.00   566704999         False   1332989843
#
#                                              name  \
# 0  Elsewhere Studios artist-in-residency program!
# 1     Martin Luther King Jr. Sculpture on Campus!
# 2   EMERGENCE: Surreal Oil Paintings by J.J. Long
# 3    1000 Artists: Presidential Inauguration 2013
# 4                                    P.M.A.F.T.W.
#
#                                                photo  pledged  \
# 0  {"small":"https://ksr-ugc.imgix.net/assets/011...  3596.00
# 1  {"small":"https://ksr-ugc.imgix.net/assets/011...  4117.00
# 2  {"small":"https://ksr-ugc.imgix.net/assets/011...  3125.00
# 3  {"small":"https://ksr-ugc.imgix.net/assets/011...  4586.00
# 4  {"small":"https://ksr-ugc.imgix.net/assets/011...  1036.00
#
#                                              profile  \
# 0  {"background_image_opacity":0.8,"should_show_f...
# 1  {"background_image_opacity":0.8,"should_show_f...
# 2  {"background_image_opacity":0.8,"should_show_f...
# 3  {"background_image_opacity":0.8,"should_show_f...
# 4  {"background_image_opacity":0.8,"should_show_f...
#
#                                             slug  \
# 0  elsewhere-studios-artist-in-residency-program
# 1      martin-luther-king-jr-sculpture-on-campus
# 2     emergence-surreal-oil-paintings-by-jj-long
# 3    1000-artists-presidential-inauguration-2013
# 4                                         pmaftw
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...       True       False
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 2  https://www.kickstarter.com/discover/categorie...       True       False
# 3  https://www.kickstarter.com/discover/categorie...       True       False
# 4  https://www.kickstarter.com/discover/categorie...       True       False
#
#         state  state_changed_at  static_usd_rate  \
# 0  successful        1334866560             1.00
# 1  successful        1334959598             1.00
# 2  successful        1334635143             1.00
# 3  successful        1336440145             1.00
# 4  successful        1333421843             1.00
#
#                                                 urls  usd_pledged  usd_type  \
# 0  {"web":{"project":"https://www.kickstarter.com...      3596.00  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...      4117.00  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...      3125.00  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...      4586.00  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...      1036.00  domestic
#
#                                             location friends is_backing  \
# 0  {"country":"US","urls":{"web":{"discover":"htt...     NaN        NaN
# 1  {"country":"US","urls":{"web":{"discover":"htt...     NaN        NaN
# 2  {"country":"US","urls":{"web":{"discover":"htt...     NaN        NaN
# 3  {"country":"US","urls":{"web":{"discover":"htt...     NaN        NaN
# 4  {"country":"US","urls":{"web":{"discover":"htt...     NaN        NaN
#
#   is_starred permissions
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
df.shape
# Out:
# (191573, 37)

# %%
df.isnull().sum()
# Out:
# backers_count                    0
# blurb                           11
# category                         0
# converted_pledged_amount         0
# country                          0
# created_at                       0
# creator                          0
# currency                         0
# currency_symbol                  0
# currency_trailing_code           0
# current_currency                 0
# deadline                         0
# disable_communication            0
# fx_rate                          0
# goal                             0
# id                               0
# is_starrable                     0
# launched_at                      0
# name                             1
# photo                            0
# pledged                          0
# profile                          0
# slug                             0
# source_url                       0
# spotlight                        0
# staff_pick                       0
# state                            0
# state_changed_at                 0
# static_usd_rate                  0
# urls                             0
# usd_pledged                      0
# usd_type                       216
# location                      1348
# friends                     191405
# is_backing                  191405
# is_starred                  191405
# permissions                 191405
# dtype: int64

# %%
df.location=df.location.fillna('short_name":"Undefined')

cat, sub, loc, duration = [],[],[],[]

for i in range(0,len(df)):
    sub.append(re.search('(?<="name":")\w+(.[a-zA-Z]+)(.[a-zA-Z]+)?', df.category.iloc[i]).group())
    cat.append(re.search('(?<="slug":")\w+', df.category.iloc[i]).group().capitalize())
    loc.append(re.search('(?<=short_name":")(....)?[-]?([a-zA-Z]+)?\s?[-]?([a-zA-Z]+)?', df.location.iloc[i]).group())
    duration.append(abs((datetime.strptime(datetime.fromtimestamp(df.deadline[i]).strftime('%Y-%m-%d'),'%Y-%m-%d') 
                 - datetime.strptime(datetime.fromtimestamp(df.launched_at[i]).strftime('%Y-%m-%d'),'%Y-%m-%d'))).days)
    
df['category'], df['subcategory'], df['location'], df['duration'] = cat, sub, loc, duration

# %%
df=df[['backers_count', 'category', 'country', 'disable_communication', 'goal', 'staff_pick',
       'state', 'usd_pledged', 'location','subcategory', 'duration']]

# %%
df.isnull().sum()
# Out:
# backers_count            0
# category                 0
# country                  0
# disable_communication    0
# goal                     0
# staff_pick               0
# state                    0
# usd_pledged              0
# location                 0
# subcategory              0
# dur                      0
# dtype: int64

# %%
df.state.unique()
# Out:
# array(['successful', 'live', 'canceled', 'failed', 'suspended'],
#       dtype=object)

# %%
df.state=list(map(lambda x: x.replace('canceled', 'failed') , df.state))
df.state=list(map(lambda x: x.replace('suspended', 'failed') , df.state))

# %%
df.head()
# Out:
#    backers_count category country  disable_communication    goal  staff_pick  \
# 0             80      Art      US                  False 2800.00       False
# 1             47      Art      US                  False 3900.00       False
# 2             80      Art      US                  False  750.00       False
# 3             82      Art      US                  False 4500.00       False
# 4             31      Art      US                  False 1000.00       False
#
#         state  usd_pledged     location  subcategory  dur
# 0  successful      3596.00       Paonia  Mixed Media   22
# 1  successful      4117.00  Bakersfield          Art   23
# 2  successful      3125.00       Lowell     Painting   19
# 3  successful      4586.00   Washington   Public Art   40
# 4  successful      1036.00     Portland     Painting    5

# %% [markdown]
# # 3. Data Exploration

# %%
df.groupby('state').state.count()
# Out:
# state
# failed         81521
# live            6578
# successful    103474
# Name: state, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.set(style="whitegrid")
sns.countplot(y="country", data=df, color='#3366ff')

# %%
countries=df.groupby(['country', 'state']).count()['goal']
countries=countries[countries.index.get_level_values('state').isin(['successful', 'failed'])]
plt.figure(figsize=(20,10))
sns.barplot(y=countries.index.get_level_values('country').unique(),x=[1 for i in range(1,len(list(countries)),2)],color='#a3ccf5', orient="h")
sns.barplot(y=countries.index.get_level_values('country').unique(),x=[countries[i]/(countries[i-1]+countries[i]) for i in range(1,len(list(countries)),2)],color='#3366ff',orient="h")

# %%
locn=list(df.groupby('location').location.count()[df.groupby('location').location.count()>1000].index)
locc=list(df.groupby('location').location.count()[df.groupby('location').location.count()>1000])
plt.figure(figsize=(20,10))
sns.barplot(y=locn,x=locc,color='#3366ff',orient="h")

# %%
cts = df.groupby(['location', 'state']).count()['goal']
cts = cts[cts.index.get_level_values('state').isin(['successful', 'failed'])]
cts = cts[cts.index.get_level_values('location').isin(['New York', 'London', 'Los Angeles', 'Chicago', 
                                                       'San Francisco','Brooklyn','Portland', 'Seattle', 
                                                       'Austin', 'Boston', 'Atlanta', 'Philadelphia',
                                                       'Minneapolis','San Diego', 'Toronto'])]
plt.figure(figsize=(20,10))
sns.barplot(y=cts.index.get_level_values('location').unique(),x=[1 for i in range(1,len(list(cts)),2)],color='#a3ccf5',orient="h")
sns.barplot(y=cts.index.get_level_values('location').unique(),x=[cts[i]/(cts[i-1]+cts[i]) for i in range(1,len(list(cts)),2)],color='#3366ff',orient="h")

# %%
plt.figure(figsize=(20,10))
sns.distplot(df.goal, bins=50)
plt.ticklabel_format(style='plain', axis='both')

# %%
df.goal.describe()
# Out:
# count      191573.00
# mean        47364.81
# std       1213734.49
# min             0.01
# 25%          1500.00
# 50%          5000.00
# 75%         13000.00
# max     100000000.00
# Name: goal, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.boxplot(y='goal',x='state', data=df, color='b')
plt.ticklabel_format(style='plain', axis='y')

# %%
plt.figure(figsize=(20,10))
sns.boxplot(y='backers_count',x='state', data=df, color='b')
plt.ticklabel_format(style='plain', axis='y')

# %%
plt.figure(figsize=(20,10))
sns.set(style="whitegrid")
sns.countplot(y="category", data=df, color='#3366ff')

# %%
categories=df.groupby(['category', 'state']).count()['goal']
categories=categories[categories.index.get_level_values('state').isin(['successful', 'failed'])]

plt.figure(figsize=(20,10))
sns.barplot(y=categories.index.get_level_values('category').unique(),x=[1 for i in range(1,len(list(categories)),2)],color='#a3ccf5', orient="h")
sns.barplot(y=categories.index.get_level_values('category').unique(),x=[categories[i]/(categories[i-1]+categories[i]) for i in range(1,len(list(categories)),2)],color='#3366ff',orient="h")

# %%
plt.figure(figsize=(20,10))
sns.distplot(df.duration)

# %%
durations=df.groupby(['duration', 'state']).count()['goal']
durations=durations[durations.index.get_level_values('state').isin(['successful', 'failed'])]

plt.figure(figsize=(20,10))
plt.scatter(durations.index.get_level_values('duration').unique(),[list(durations)[i]/(list(durations)[i-1]+list(durations)[i]) for i in range(1,len(list(durations)),2)])

# %% [markdown]
# # 4. Preprocessing

# %%
state = {'state': {'failed': 0,'successful': 1, 'live': 2 }}
df.replace(state, inplace=True)

df['category']=df['category'].astype('category')
df['category']=df['category'].cat.codes

df['subcategory']=df['subcategory'].astype('category')
df['subcategory']=df['subcategory'].cat.codes

df['location']=df['location'].astype('category')
df['location']=df['location'].cat.codes

df['country']=df['country'].astype('category')
df['country']=df['country'].cat.codes

df.disable_communication=df.disable_communication.astype(int)
df.staff_pick = df.staff_pick.astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-745-fbae6623ecfd> in <module>()
#       1 state = {'state': {'failed': 0,'successful': 1, 'live': 2 }}
# ----> 2 df.replace(state, inplace=True)
#       3
#       4 df['category'] = df['category'].astype('category')
#       5 df['category'] = df['category'].cat.codes
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    4529
#    4530             return self.replace(to_replace, value, inplace=inplace,
# -> 4531                                 limit=limit, regex=regex)
#    4532         else:
#    4533
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    4548                                                     value=value[c],
#    4549                                                     inplace=False,
# -> 4550                                                     regex=regex)
#    4551                     return None if inplace else res
#    4552
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    4578                                                        dest_list=value,
#    4579                                                        inplace=inplace,
# -> 4580                                                        regex=regex)
#    4581
#    4582                 else:  # [NA, ''] -> 0
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in replace_list(self, src_list, dest_list, inplace, regex, mgr)
#    3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
# -> 3487         masks = [comp(s) for i, s in enumerate(src_list)]
#    3488
#    3489         result_blocks = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
# -> 3487         masks = [comp(s) for i, s in enumerate(src_list)]
#    3488
#    3489         result_blocks = []
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in comp(s)
#    3483             if isna(s):
#    3484                 return isna(values)
# -> 3485             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3486
#    3487         masks = [comp(s) for i, s in enumerate(src_list)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in _maybe_compare(a, b, op)
#    4945             type_names[1] = 'ndarray(dtype=%s)' % b.dtype
#    4946
# -> 4947         raise TypeError("Cannot compare types %r and %r" % tuple(type_names))
#    4948     return result
#    4949
#
# TypeError: Cannot compare types 'ndarray(dtype=int64)' and 'str'

# %%
df.head()
# Out:
#    backers_count  category  country  disable_communication    goal  \
# 0             80         0       21                      0 2800.00
# 1             47         0       21                      0 3900.00
# 2             80         0       21                      0  750.00
# 3             82         0       21                      0 4500.00
# 4             31         0       21                      0 1000.00
#
#    staff_pick  state  usd_pledged  location  subcategory  dur
# 0           0      1      3596.00      7858           86   22
# 1           0      1      4117.00       524           10   23
# 2           0      1      3125.00      5966           95   19
# 3           0      1      4586.00     11132          113   40
# 4           0      1      1036.00      8282           95    5

# %%
sns.heatmap(data=df.corr())

# %% [markdown]
# # 5. Modeling

# %%
#To be continued...
